# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %cd /content/drive/Othercomputers/My MacBook Air/Project_DL&IVP/
# Out:
# /content/drive/Othercomputers/My MacBook Air/Project_DL&IVP

# %%
image = np.load("f606w_image.npy")

# %%
mask =  np.load("f606w_mask.npy")

# %%
ignore = np.load("f606w_ignore.npy")

# %%
image.shape
# Out:
# (8820, 256, 256)

# %%
mask.shape
# Out:
# (8820, 256, 256)

# %%
ignore.shape
# Out:
# (8820, 256, 256)

# %%
k = 0

# %%
plt.imshow(image[k],cmap='gray')

# %%
plt.imshow(mask[k],cmap='gray')

# %%
plt.imshow(ignore[k],cmap='gray')
